# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('job-market.csv')
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
plt.figure(figsize=(15,15))
plt1 = sns.countplot( y = 'Location',
              data = df,
              order = df['Location'].value_counts().index)
plt1.set(xlabel = 'Number of Jobs', ylabel = 'Location', title = 'Number of Jobs by Location')
# Out:
# [Text(0.5, 0, 'Number of Jobs'),
#  Text(0, 0.5, 'Location'),
#  Text(0.5, 1.0, 'Number of Jobs by Location')]

# %%
df[['LowestSalary','HighestSalary']].count()
# Out:
# LowestSalary     10099
# HighestSalary    10099
# dtype: int64

# %%
df[['LowestSalary','HighestSalary']].value_counts()
# Out:
# LowestSalary  HighestSalary
# 0.0           30.0             3894
# 40.0          50.0             2519
# 50.0          60.0             1844
# 30.0          40.0             1842
# dtype: int64

# %%
# Pie chart info for job posts for salary range.
labels = ['0-30', '30-40', '40-50', '50-60']
data = df[['LowestSalary','HighestSalary']].value_counts()

# Plot pie chart
fig1, ax1 = plt.subplots()
ax1.pie(data, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
#draw inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt1 = sns.countplot( y = 'Classification',
              data = df,
              order = df['Classification'].value_counts().index)
plt1.set(xlabel = 'Number of Job Classifications', ylabel = 'Classification', title = 'Number of Jobs by Classification')
# Out:
# [Text(0.5, 0, 'Number of Job Classifications'),
#  Text(0, 0.5, 'Classification'),
#  Text(0.5, 1.0, 'Number of Jobs by Classification')]
